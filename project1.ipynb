# %%
import pandas as pd
df=pd.read_csv('collections/people.csv')
df
df[' capital-gain'].sum()
# Out:
# 35089324

# %% [markdown]
# 1. List our various countries.Do not duplicate country names

# %%
df[' native-country']
# Out:
# 0         United-States
# 1         United-States
# 2         United-States
# 3         United-States
# 4                  Cuba
#               ...
# 32556     United-States
# 32557     United-States
# 32558     United-States
# 32559     United-States
# 32560     United-States
# Name:  native-country, Length: 32561, dtype: object

# %%
df[' native-country'].drop_duplicates()
# Out:
# 0                      United-States
# 4                               Cuba
# 6                            Jamaica
# 11                             India
# 14                                 ?
# 15                            Mexico
# 27                             South
# 35                       Puerto-Rico
# 52                          Honduras
# 98                           England
# 112                           Canada
# 122                          Germany
# 135                             Iran
# 152                      Philippines
# 201                            Italy
# 217                           Poland
# 228                         Columbia
# 255                         Cambodia
# 265                         Thailand
# 289                          Ecuador
# 304                             Laos
# 311                           Taiwan
# 338                            Haiti
# 359                         Portugal
# 427               Dominican-Republic
# ...

# %% [markdown]
# 2. List our various education types.Do not duplicate education types.

# %%
df[' education'].drop_duplicates()
# Out:
# 0          Bachelors
# 2            HS-grad
# 3               11th
# 5            Masters
# 6                9th
# 10      Some-college
# 13        Assoc-acdm
# 14         Assoc-voc
# 15           7th-8th
# 20         Doctorate
# 52       Prof-school
# 56           5th-6th
# 77              10th
# 160          1st-4th
# 224        Preschool
# 415             12th
# Name:  education, dtype: object

# %% [markdown]
# 3. List our unique countries where people live between the ages of 31 to 35.

# %%
dfres=df.loc[df['age'].between(31,35),' native-country'].value_counts()
dfres
# Out:
#  native-country
# United-States         3865
# Mexico                 103
# ?                       90
# Philippines             27
# Germany                 25
# India                   19
# Puerto-Rico             16
# Jamaica                 16
# China                   14
# England                 13
# El-Salvador             12
# Canada                  11
# South                   10
# Japan                   10
# Cuba                    10
# Taiwan                   9
# Columbia                 9
# Iran                     8
# Ireland                  7
# Guatemala                7
# Italy                    7
# France                   7
# Nicaragua                5
# Vietnam                  5
# Portugal                 5
# Haiti                    5
# Peru                     4
# Trinadad&Tobago          4
# Ecuador                  4
# Hong                     4
# Dominican-Republic       4
# Thailand                 3
# Yugoslavia               3
# ...

# %%
df1=df.loc[df[' native-country']==' Laos'].value_counts()
df1
# Out:
# age   workclass    fnlwgt   education     education-num   marital-status         occupation         relationship   race                sex     capital-gain   capital-loss   hours-per-week   native-country
# 19   ?            109938   11th          7               Married-civ-spouse     ?                  Wife           Asian-Pac-Islander  Female  0              0              40               Laos               1
#      Private      301911   Some-college  10              Never-married          Sales              Own-child      Asian-Pac-Islander  Male    0              0              35               Laos               1
# 53   Private      97411    5th-6th       3               Married-civ-spouse     Machine-op-inspct  Husband        Asian-Pac-Islander  Male    0              0              40               Laos               1
# ...

# %% [markdown]
# 4. Calculate the capital gain of people whose relationship is husbands .

# %%
dfgain=df.loc[df[' relationship']==' Husband'].value_counts()
dfgain
# Out:
# age   workclass         fnlwgt   education     education-num   marital-status      occupation         relationship   race   sex   capital-gain   capital-loss   hours-per-week   native-country
# 38   Private           207202   HS-grad       9               Married-civ-spouse  Machine-op-inspct  Husband        White  Male  0              0              48               United-States      2
# 39   Private           30916    HS-grad       9               Married-civ-spouse  Craft-repair       Husband        White  Male  0              0              40               United-States      2
#                        138192   Bachelors     13              Married-civ-spouse  Craft-repair       Husband        White  Male  0              0              40               United-States      2
# 42   Private           204235   Some-college  10              Married-civ-spouse  Prof-specialty     Husband        White  Male  0              0              40               United-States      2
# ...

# %% [markdown]
# 5.How many people never married?

# %%
nmarried=df.loc[df[' marital-status']==' Never-married']
nmarried.value_counts()
# Out:
# age   workclass         fnlwgt   education     education-num   marital-status   occupation         relationship   race   sex     capital-gain   capital-loss   hours-per-week   native-country
# 25   Private           195994   1st-4th       2               Never-married    Priv-house-serv    Not-in-family  White  Female  0              0              40               Guatemala          3
# 27   Private           255582   HS-grad       9               Never-married    Machine-op-inspct  Not-in-family  White  Female  0              0              40               United-States      2
# 28   Private           274679   Masters       14              Never-married    Prof-specialty     Not-in-family  White  Male    0              0              50               United-States      2
# 23   Private           240137   5th-6th       3               Never-married    Handlers-cleaners  Not-in-family  White  Male    0              0              55               Mexico             2
# ...

# %% [markdown]
# 6. List out the different types of education with their percentage with overall data.

# %%
df[' education'].value_counts()
# Out:
#  education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64

# %%
df[' education-num'].groupby(df[' education']).mean()
# df[' education-num'].value_counts().mean()
# Out:
#  education
# 10th             6.0
# 11th             7.0
# 12th             8.0
# 1st-4th          2.0
# 5th-6th          3.0
# 7th-8th          4.0
# 9th              5.0
# Assoc-acdm      12.0
# Assoc-voc       11.0
# Bachelors       13.0
# Doctorate       16.0
# HS-grad          9.0
# Masters         14.0
# Preschool        1.0
# Prof-school     15.0
# Some-college    10.0
# Name:  education-num, dtype: float64

# %% [markdown]
# 7.Calculate the percentage of various conuntries in overall data.

# %%
import pandas as pd
df=pd.read_csv('collections/people.csv')
df
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.groupby([ 'native-country']).mean()

# %% [markdown]
# 8. How many people doing tech support as an occupation?

# %%
dftech=df.loc[df[' occupation']==' Tech-support']
dftech
# Out:
#        age   workclass   fnlwgt      education   education-num  \
# 24      59     Private   109015        HS-grad               9
# 25      56   Local-gov   216851      Bachelors              13
# 42      24     Private   172987      Bachelors              13
# 55      43     Private   237993   Some-college              10
# 64      29     Private   105598   Some-college              10
# ...    ...         ...      ...            ...             ...
# 32396   56     Private   135458        HS-grad               9
# 32457   33     Private   139057        Masters              14
# 32546   37     Private   198216     Assoc-acdm              12
# 32553   32     Private   116138        Masters              14
# 32556   27     Private   257302     Assoc-acdm              12
#
#             marital-status     occupation    relationship  \
# 24                Divorced   Tech-support       Unmarried
# 25      Married-civ-spouse   Tech-support         Husband
# ...

# %% [markdown]
# 9.considering the sum of data, which education is high capital gain?

# %%
dfmax=df[' education'].groupby(df[' capital-gain']).max()

df1=dfmax.value_counts()
df1
# Out:
#  education
# Some-college    80
# HS-grad         14
# Masters         11
# Prof-school      5
# Bachelors        3
# 9th              2
# Assoc-voc        1
# Doctorate        1
# 7th-8th          1
# Preschool        1
# Name: count, dtype: int64

# %% [markdown]
# 10. what is % of male and female data

# %%
# res=df.groupby(df[' sex'])
df.groupby(df[' sex']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/Example/.venv/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/Documents/Example/.venv/lib/python3.11/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/Documents/Example/.venv/lib/python3.11/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...

# %% [markdown]
# 11. Displat the average capital gain in descending order for all the various occupation.

# %%
# df.groupby([' capital-gain']).mean()
# dfs=df.loc[df[' capital-gain'].mean(),[' occupation']]
# dfs
dfs=df[' capital-gain'].groupby(df[' occupation']).mean()
dfs.sort_values(ascending=False)
# Out:
#  occupation
# Prof-specialty       2726.699517
# Exec-managerial      2262.772996
# Sales                1319.829315
# Protective-serv       708.098613
# Tech-support          673.552802
# Craft-repair          649.512808
# ?                     604.491047
# Farming-fishing       589.726358
# Adm-clerical          495.954907
# Transport-moving      490.323732
# Machine-op-inspct     328.689311
# Priv-house-serv       279.852349
# Handlers-cleaners     257.572993
# Other-service         191.301669
# Armed-Forces            0.000000
# Name:  capital-gain, dtype: float64

# %% [markdown]
# 12. what is the average salary of unmarried people

# %%
# dfs=df.loc[df[' marital-status']==' Never-married',[' capital-gain']]
# dfs[' marital-status'].
dfs=df[' capital-gain'].groupby(df[' relationship']==' Unmarried').mean()
dfs
# Out:
#  relationship
# False    1151.340787
# True      455.031050
# Name:  capital-gain, dtype: float64

# %% [markdown]
# 13. How many people work in local government?

# %%
dftech=df.loc[df[' workclass']==' Local-gov']
dftech
# Out:
#        age   workclass   fnlwgt    education   education-num  \
# 25      56   Local-gov   216851    Bachelors              13
# 30      23   Local-gov   190709   Assoc-acdm              12
# 79      31   Local-gov   125927      7th-8th               4
# 86      49   Local-gov   268234      HS-grad               9
# 94      34   Local-gov   226296    Bachelors              13
# ...    ...         ...      ...          ...             ...
# 32502   35   Local-gov    79649    Bachelors              13
# 32511   25   Local-gov   514716    Bachelors              13
# 32518   57   Local-gov   110417      HS-grad               9
# 32543   45   Local-gov   119199   Assoc-acdm              12
# 32545   39   Local-gov   111499   Assoc-acdm              12
#
#             marital-status        occupation    relationship    race      sex  \
# 25      Married-civ-spouse      Tech-support         Husband   White     Male
# ...

# %%
dftech.value_counts()
# Out:
# age   workclass   fnlwgt   education     education-num   marital-status      occupation       relationship   race   sex     capital-gain   capital-loss   hours-per-week   native-country
# 17   Local-gov   32124    9th           5               Never-married       Other-service    Own-child      Black  Male    0              0              9                United-States      1
# 47   Local-gov   123681   Masters       14              Married-civ-spouse  Prof-specialty   Husband        White  Male    7688           0              60               United-States      1
#                  114459   Masters       14              Married-civ-spouse  Prof-specialty   Husband        White  Male    7688           0              45               United-States      1
#                  109705   HS-grad       9               Divorced            Exec-managerial  Not-in-family  White  Female  0              0              40               United-States      1
# ...

# %% [markdown]
# 15.What is sum of capital gains of never married and divorced people

# %%
dfgain=df.loc[df[' marital-status'].isin([' Never-married',' Divorced'])]
dfgain[' capital-gain'].sum()
# Out:
# 7259440

# %%
fgain=df.loc[df[' marital-status'].isin([' Divorced'])]
fgain[' capital-gain'].sum()
# Out:
# 3236347

# %%
dfgain=df.loc[df[' marital-status'].isin([' Never-married'])]
dfgain[' capital-gain'].sum()
# Out:
# 4023093

# %% [markdown]
# 16. How many people didnot go to college?

# %% [markdown]
# 17. How many people work 40 hours per week?

# %%
df.groupby(df[' hours-per-week']==40).count()
# Out:
#                    age   workclass   fnlwgt   education   education-num  \
#  hours-per-week
# False            17344       17344    17344       17344           17344
# True             15217       15217    15217       15217           15217
#
#                   marital-status   occupation   relationship   race    sex  \
#  hours-per-week
# False                      17344        17344          17344  17344  17344
# True                       15217        15217          15217  15217  15217
#
#                   capital-gain   capital-loss   hours-per-week  \
#  hours-per-week
# False                    17344          17344            17344
# True                     15217          15217            15217
#
#                   native-country
#  hours-per-week
# False                      17344
# True                       15217

# %% [markdown]
# 18.Describe the data set

# %%
df.describe()
# Out:
#                 age        fnlwgt   education-num   capital-gain  \
# count  32561.000000  3.256100e+04    32561.000000   32561.000000
# mean      38.581647  1.897784e+05       10.080679    1077.648844
# std       13.640433  1.055500e+05        2.572720    7385.292085
# min       17.000000  1.228500e+04        1.000000       0.000000
# 25%       28.000000  1.178270e+05        9.000000       0.000000
# 50%       37.000000  1.783560e+05       10.000000       0.000000
# 75%       48.000000  2.370510e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week
# count   32561.000000     32561.000000
# mean       87.303830        40.437456
# std       402.960219        12.347429
# min         0.000000         1.000000
# 25%         0.000000        40.000000
# 50%         0.000000        40.000000
# 75%         0.000000        45.000000
# max      4356.000000        99.000000

# %% [markdown]
# 19.Display the percentage of race in descending order?

# %%
import pandas as pd
df=pd.read_csv('collections/people.csv')
df
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dfs=df.groupby(df[' race'],sort=False)
dfs.count()
# Out:
#                       age   workclass   fnlwgt   education   education-num  \
#  race
# White               27816       27816    27816       27816           27816
# Black                3124        3124     3124        3124            3124
# Asian-Pac-Islander   1039        1039     1039        1039            1039
# Amer-Indian-Eskimo    311         311      311         311             311
# Other                 271         271      271         271             271
#
#                      marital-status   occupation   relationship    sex  \
#  race
# White                         27816        27816          27816  27816
# Black                          3124         3124           3124   3124
# Asian-Pac-Islander             1039         1039           1039   1039
# Amer-Indian-Eskimo              311          311            311    311
# Other                           271          271            271    271
#
#                      capital-gain   capital-loss   hours-per-week  \
# ...

# %% [markdown]
# 20. How many private-sector employees never-married?

# %%
df.loc[df[' marital-status']==' Divorced'].groupby(df[' workclass']==' Private').count()
# Out:
#              age   workclass   fnlwgt   education   education-num  \
#  workclass
# False       1324        1324     1324        1324            1324
# True        3119        3119     3119        3119            3119
#
#              marital-status   occupation   relationship   race   sex  \
#  workclass
# False                  1324         1324           1324   1324  1324
# True                   3119         3119           3119   3119  3119
#
#              capital-gain   capital-loss   hours-per-week   native-country
#  workclass
# False                1324           1324             1324             1324
# True                 3119           3119             3119             3119

# %%
df.loc[df[' workclass']==' Private'].groupby(df[' marital-status']==' Never-married').count()
# Out:
#                    age   workclass   fnlwgt   education   education-num  \
#  marital-status
# False            14510       14510    14510       14510           14510
# True              8186        8186     8186        8186            8186
#
#                   marital-status   occupation   relationship   race    sex  \
#  marital-status
# False                      14510        14510          14510  14510  14510
# True                        8186         8186           8186   8186   8186
#
#                   capital-gain   capital-loss   hours-per-week  \
#  marital-status
# False                    14510          14510            14510
# True                      8186           8186             8186
#
#                   native-country
#  marital-status
# False                      14510
# True                        8186

# %% [markdown]
# 21. consider 0 as null values,drop null values and find how many rows in the dataset

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('collections/people.csv')
dfres=df.replace(0,np.nan)
dfres.count()
# dfres.dropna().count()
# Out:
# age                32561
#  workclass         32561
#  fnlwgt            32561
#  education         32561
#  education-num     32561
#  marital-status    32561
#  occupation        32561
#  relationship      32561
#  race              32561
#  sex               32561
#  capital-gain       2712
#  capital-loss       1519
#  hours-per-week    32561
#  native-country    32561
# dtype: int64

# %% [markdown]
# 22. Calculate the sum of capital gain for india and united states

# %%
import pandas as pd
df=pd.read_csv('collections/people.csv')

# %%
dfsum=df.loc[df[' native-country'].isin([' India',' United-States'])]
# dfsum.value_counts()
s_capital=dfsum[' capital-gain'].value_counts()
s_capital.sum()
# s_capital.sum()
# Out:
# 29270

# %% [markdown]
# 23. Replace all 0 values with 100 without using the replace function

# %%
df[df==0]=100
df.value_counts()
# Out:
# age   workclass         fnlwgt   education     education-num   marital-status      occupation         relationship   race   sex     capital-gain   capital-loss   hours-per-week   native-country
# 25   Private           195994   1st-4th       2               Never-married       Priv-house-serv    Not-in-family  White  Female  100            100            40               Guatemala          3
# 23   Private           240137   5th-6th       3               Never-married       Handlers-cleaners  Not-in-family  White  Male    100            100            55               Mexico             2
# 38   Private           207202   HS-grad       9               Married-civ-spouse  Machine-op-inspct  Husband        White  Male    100            100            48               United-States      2
# 49   Self-emp-not-inc  43479    Some-college  10              Married-civ-spouse  Craft-repair       Husband        White  Male    100            100            40               United-States      2
# ...

# %% [markdown]
# 24. What is the % of the relationship between education-num and capital gain

# %%
df[' capital-gain'].groupby(df[' education-num']).value_counts()
dfsum=df[' capital-gain'].groupby(df[' education-num'])
dfsum.mean()
# d=df[' capital-gain'].groupby(df[' education-num']==1)
# d.mean()
# Out:
#  education-num
# 1       898.392157
# 2       125.875000
# 3       176.021021
# 4       233.939628
# 5       342.089494
# 6       404.574491
# 7       215.097872
# 8       284.087760
# 9       576.800114
# 10      598.824167
# 11      715.051375
# 12      640.399250
# 13     1756.299533
# 14     2562.563552
# 15    10414.416667
# 16     4770.145278
# Name:  capital-gain, dtype: float64

# %% [markdown]
# 25. Do under-sampling of data to 10,000 rows without replacement?

# %%
df.sample(n=10000,replace=False)
# Out:
#        age   workclass   fnlwgt      education   education-num  \
# 6690    60     Private   199085           10th               6
# 27983   46     Private   122026        HS-grad               9
# 578     58   Local-gov   283635      Bachelors              13
# 7278    37     Private   333305      Doctorate              16
# 18280   65     Private   129426   Some-college              10
# ...    ...         ...      ...            ...             ...
# 31355   42   Local-gov   121012   Some-college              10
# 12099   38     Private   269323        HS-grad               9
# 32429   51   Local-gov   203334      Doctorate              16
# 8326    20     Private    33644        HS-grad               9
# 2851    20   State-gov   243986   Some-college              10
#
#             marital-status          occupation    relationship    race  \
# 6690    Married-civ-spouse   Machine-op-inspct         Husband   White
# ...

# %% [markdown]
# 26. what is most frequent country?

# %%
fre=df[' native-country'].value_counts()
fre
# Out:
#  native-country
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# ...

# %% [markdown]
# 27. What is the sum of capital gain where divorced people who didnot go to college for highter degrees?

# %%
sum_captial=df.groupby(df[' marital-status']==' Divorced')
sum_captial.value_counts()
# final=sum_captial[[' education']!=' HS-grad']
# final
# Out:
#  marital-status  age   workclass     fnlwgt   education     education-num   marital-status   occupation       relationship   race   sex     capital-gain   capital-loss   hours-per-week   native-country
# False            25   Private       195994   1st-4th       2               Never-married    Priv-house-serv  Not-in-family  White  Female  100            100            40               Guatemala          3
#                  19   Private       97261    HS-grad       9               Never-married    Farming-fishing  Not-in-family  White  Male    100            100            40               United-States      2
#                                     138153   Some-college  10              Never-married    Adm-clerical     Own-child      White  Female  100            100            10               United-States      2
# ...

# %% [markdown]
# 28. Can you explain the relationship between education and marital status?

# %%
rel_btn=df[' education'].groupby(df[' marital-status'])
final_res=rel_btn.value_counts()
final_res
# Out:
#  marital-status   education
# Divorced         HS-grad         1613
#                  Some-college    1069
#                  Bachelors        546
#                  Assoc-voc        234
#                  Masters          233
#                                  ...
# Widowed          5th-6th           14
#                  12th              10
#                  Doctorate          7
#                  Prof-school        5
#                  Preschool          3
# Name: count, Length: 101, dtype: int64

# %% [markdown]
# 29. Consider the ? are nan values,drop those rows and display the % of data based on marital status?

# %% [markdown]
# 29. Consider the ? are nan values, drop those rows, and display the % of data based on marital status

# %% [markdown]
# 30. Based on the given data which occupation do you prefer for your career and why?
